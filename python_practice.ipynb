# %% [markdown]
# <a href="https://colab.research.google.com/github/sivanjelly04/projects-/blob/main/python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World ")

character_name = "Max"
print("There was a girl named " + character_name)
character_name.replace("Max", "Sarah")
print(character_name + " loves to play sports")

im_female = True
print(not(im_female))

print("do", "you".upper(), "know", "THAT".lower())

object = "umbrella"
object.index("a")

print (7 * 3)
print (10 % 3)

pow(3,2)
max(12,19)
sqrt(64)

from math import *
ceil(3.2)
floor(9.7)

num1 = input("Enter a number: ")
num2 = input("Enter a second number: ")
result = int(num1) + int(num2)
print(result)
# Out:
# Hello World
# There was a girl named Max
# Max loves to play sports
# False
# do YOU know that
# 21
# 1
# Enter a number: 5
# Enter a second number: 4
# 9

# %%
flavours = ["vanilla", "chocolate", "mango", "mint"]
flavours.append("strawberry")
flavours.insert(1, "red bean")
flavours.pop()
flavours.sort()
print(flavours)

print(flavours.index("chocolate"))
flavours2 = flavours.copy()
print(flavours2)

def say_hello():
  print ("apple")
say_hello()

is_hungry = True
if is_hungry:
  print("go eat something ")
else:
  print(" skinny queen ")

def max_num(num1, num2, num3):
  if num1>=num2 and num1>=num3:
    return num1
  if num3>=num2 and num3>=num1:
    return num3
  else:
    return num2

max_num(4,9,3)

p=3
while p <= 10:
  print(p)
  p+=1
print("Done with loop")
# Out:
# ['chocolate', 'mango', 'mint', 'red bean', 'vanilla']
# 0
# ['chocolate', 'mango', 'mint', 'red bean', 'vanilla']
# apple
# go eat something
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# Done with loop
