# %% [markdown]
# <a href="https://colab.research.google.com/github/sivanjelly04/projects-/blob/main/guessing_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

num = random.randint(1,100)
guess_count = 0
guess_limit = 4
out_of_guesses = False

while True:
  try:
    guess = int(input("Guess a number between 1 and 100: "))
    if guess_count < guess_limit:
      guess_count += 1
    else:
      out_of_guesses == True
      print("Out of guesses! ")
      break

    if guess > num:
      print("Try lower! ")
    elif guess < num:
      print("Try higher! ")
    else:
      print("You win!")
      break2
  except ValueError:
      print("Invalid")
# Out:
# Guess a number between 1 and 100: 68
# Try lower!
# Guess a number between 1 and 100: 54
# Try lower!
# Guess a number between 1 and 100: 45
# Try lower!
# Guess a number between 1 and 100: 34
# Try lower!
# Guess a number between 1 and 100: 23
# Out of guesses!

# %%
secret_word = "butterfly"
guess = ()
guess_count = 0
guess_limit = 3
out_of_guesses = False

while True:

    if guess != secret_word and guess_count < guess_limit:
      guess = input("Guess the secret word: ")
      guess_count += 1
    else:
      out_of_guesses = True
      print("out of guesses! \nyou lose!")
      break

    if guess == secret_word:
      print("you wins!")
      break
# Out:
# Guess the secret word: bededj
# Guess the secret word: de
# Guess the secret word: d
# out of guesses!
# you lose!
