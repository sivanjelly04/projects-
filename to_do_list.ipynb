# %% [markdown]
# <a href="https://colab.research.google.com/github/sivanjelly04/projects-/blob/main/to_do_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_task():
  task = input("Enter a task:")
  tasks.append(task)
  print(f"{task} added to the list")

def list_tasks():
  if not tasks:
    print(" There are no tasks")
  else:
    print("Current tasks")
    ## dont understand the next 2 steps..
    for index, task in enumerate(tasks):
      print(f"#{index}. {tasks}")


def del_task():
  list_tasks
  try:
   to_del = int(input("Choose a task to delete"))
   if to_del >= 0 and to_del < len(tasks):
    tasks.pop(to_del)
    print(f"{to_del} has been delected")
   else:
    print(f"{to_del} was not found.")

  except:
    print("Inavlid input, try again. ")

    print("This is the to-do list app!")
    while True:
      print("Choose an option: ")
      print("1. Add new task")
      print("2. Delete a task")
      print("3. Show list of tasks")
      print("4. Quit")

      choice = input("Enter your choice: ")
      if choice == 1:
        add_task()
      elif choice == 2:
        del_task()
      elif choice == 3:
        list_tasks()
      elif choice == 4:
        break
      else:
        print("Invalid input, Try again! ")

    print("Goodbye! :) ")
