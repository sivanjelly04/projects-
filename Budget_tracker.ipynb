# %% [markdown]
# <a href="https://colab.research.google.com/github/sivanjelly04/projects-/blob/main/Budget_tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime
# now = datetime.now()

def add_expenses:
  description = input("Describe your expense: ")
  amount = input("Enter the amount: ")
  date = datetime.now().strfrtime("%y-%m-%d") # to create the type of date
  # create file ??
  print("Expenses added successfully")

def view_expenses:
  try:
    with open("") # add the file ??
    expenses = file.readlines()

    if not expenses:
      print("No expenses found.")
      return

    print("Your Expenses")
    print("-"*40)  # check why got asterisk

    for line in expenses:
      print(line.strip())
      amount = # confusing. learn again.

      total += amount

  except FileNotFoundError: # opening a file that doesnt exist, dividing number by 0
    print("No expenses added yet. ")
